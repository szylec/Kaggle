# %%
'''You are provided with daily historical sales data. 
The task is to forecast the total amount of products sold in every shop for the test set. 
Note that the list of shops and products slightly changes every month. 
Creating a robust model that can handle such situations is part of the challenge.

Link: https://www.kaggle.com/c/competitive-data-science-predict-future-sales

My assumptions:
- I do not care about russian names, I do not understand them. I will stick to IDs. 
-- On data load will skip dictionary names: item_categories.csv and shops.csv
- Minus "-" sign at item_cnt_day means that product was returned.
- Because of negative values for target value we cannot transform using log function.
- I'm intrested in shop_id x item_id x month aggregations.
- Price can change in month so I need to take mean, median, max, min and std dev.
-- But, I will not focus on price in first iteration.
- For target value sum should be enough (to be decided if for more complex analysis is the case).
- For POC model I will work on:
-- shop_id = 31
-- item_id = 20949
'''
# %reset

# %%
import os
import datetime
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima_model import ARIMA
from pyramid.arima import auto_arima

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20, 6

# %%
FEATURES_ORIGINAL = [
    'date',
    'date_block_num',
    'shop_id',
    'item_id',
    'item_category_id',
    'item_price']
TARGET = ['item_cnt_day']
TARGET_STR = ''.join(TARGET)

TARGET_AGG = ['item_cnt_day_sum']
TARGET_STR_AGG = ''.join(TARGET_AGG)

def get_train():
    train_raw = pd.read_csv('sales_train.csv')
    items_raw = pd.read_csv('items.csv')    
    train = pd.merge(left=train_raw, right=items_raw, on='item_id', how='left')
    return train[FEATURES_ORIGINAL + TARGET]

def get_test():
    return pd.read_csv('test.csv')

def transfrom_train(train):
    # Remove date_block_num (it's useful, but I don't want to use it).
    train.drop('date_block_num', inplace=True, axis=1)
    
    # Add year, month, day columns.
    train['year'] = train['date'].apply(lambda x: x.split('.')[2])
    train['month'] = train['date'].apply(lambda x: x.split('.')[1])
    train['year_month'] = train['year'] + '_' + train['month']
    train['year_month_dt'] = train['year_month'].apply(lambda x: pd.datetime.strptime(x, '%Y_%m'))
    
    # Aggregation.
    grouped = train.groupby(
        ['year', 'month', 'year_month', 'year_month_dt', 'shop_id', 'item_id', 'item_category_id'])
    train = grouped.agg({
        'item_price': ['mean', 'max', 'min', 'std'],
        'item_cnt_day': 'sum'
    }).reset_index()
    train_columns_new = []
    for upper, lower in list(train.columns):
        column = upper + '_' + lower if lower != '' else upper
        train_columns_new.append(column)    
    train.columns = train_columns_new

    # Change ID's to qualitative - these will be my shop, item, category names.
    train.loc[:, 'shop_id'] = train['shop_id'].astype(object)
    train.loc[:, 'item_id'] = train['item_id'].astype(object)
    train.loc[:, 'item_category_id'] = train['item_category_id'].astype(object)
    
    # Remove columns that are not included in scope of first iteration.
    columns_to_remove = [x for x in list(train.columns) if x.startswith('item_price_')]
    columns_to_remove_additional = ['year', 'month']
    columns_to_keep = [x for x in list(train.columns) if x not in columns_to_remove + columns_to_remove_additional]
    
    return train[columns_to_keep]

def predict_single_ts(data, shop_id, item_id):
    timeseries = data.loc[(data['shop_id'] == shop_id) & (data['item_id'] == item_id), :]
    if not timeseries.empty:
        timeseries.index = timeseries['year_month_dt']
        timeseries = timeseries[TARGET_STR_AGG]
        try:
            stepwise_fit = auto_arima(timeseries, start_p=1, start_d=1, start_q=1, max_p=5, max_d=1, max_q=5, 
                                      seasonal=True, stationary=False, stepwise=True, error_action='ignore', suppress_warnings=True)
            prediction = stepwise_fit.predict(n_periods=1)
            prediction = round(prediction.item(), 2)
        except ValueError as e:
            prediction = np.nan
    else:
        prediction = np.nan
    return prediction

# %% [markdown]
# ## Execute

# %%
# %%time
train = get_train()
test = get_test()
train = transfrom_train(train)
# Out:
# CPU times: user 35 s, sys: 2 s, total: 37 s
# Wall time: 31.9 s

# %%
# %%time
test['prediction'] = test.apply(lambda x: predict_single_ts(data=train, shop_id=x['shop_id'], item_id=x['item_id']), axis=1)

# %% [markdown]
# ## Auxiliary Data analysis

# %%
test.tail()
# Out:
#             ID  shop_id  item_id
# 214195  214195       45    18454
# 214196  214196       45    16188
# 214197  214197       45    15757
# 214198  214198       45    19648
# 214199  214199       45      969

# %%
# Check NULLs in train.
train.isnull().sum()
# Out:
# year_month          0
# year_month_dt       0
# shop_id             0
# item_id             0
# item_category_id    0
# item_cnt_day_sum    0
# dtype: int64

# %%
# Check NULLs in test.
test.isnull().sum()
# Out:
# ID         0
# shop_id    0
# item_id    0
# dtype: int64

# %%
# Plot train_sample.
sns.pointplot(x='year_month_dt', y='item_cnt_day_sum', data=train_sample)

# %% [markdown]
# ### Qualitative data analysis

# %%
# We have 60 shops (based on shop_id)
train['shop_id'].value_counts().count()
# Out:
# 60

# %%
def _counts(column):
    grouped = train.groupby(column).agg({column: 'count'})
    grouped.columns = ['counts']
    scope_of_ids = list(grouped.reset_index()
                        .sort_values(by='counts', ascending=False).head(10).loc[:, column])
    data_viz = train[train[column].isin(scope_of_ids)]
    sns.boxplot(x=column, y=TARGET_STR_AGG, data=data_viz)

# %%
_counts('shop_id')

# %%
_counts('item_id')

# %%
_counts('item_category_id')

# %% [markdown]
# ### Stationarity

# %%
def set_train_sample(train):
    train_sample = train.loc[(train['shop_id'] == 31) & (train['item_id'] == 20949), :]
    return train_sample

train_sample = set_train_sample(train)

# %%
def set_timeseries(df):
    timeseries = df.copy()
    timeseries.index = timeseries['year_month_dt']
    timeseries = timeseries[TARGET_STR_AGG]
    timeseries.columns = [TARGET_STR_AGG]
    return timeseries

ts = set_timeseries(train_sample)

# %%
def _test_stationarity(ts, window): 
    # Calculate rolling statistics.
    rolling_mean = ts.rolling(window=window).mean()
    rolling_std = ts.rolling(window=window).std()

    # Show plots.
    original = plt.plot(ts, color='blue', label='original')
    mean = plt.plot(rolling_mean, color='red', label='mean')
    std = plt.plot(rolling_std, color='black', label='std')
    plt.title('Original timeseries, rolling mean and std.')
    plt.legend(loc='best')
    plt.show(block=False)

    # Perform stationarity test (Dickey-Fuller).
    print('Results of Dickey-Fuller Test')
    dftest = adfuller(ts, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=[
        'Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)
    
_test_stationarity(ts=ts, window=6)
# p-value = 0.026207
# Seems that timeseries might be stationary.
# Looks we have increased sales in X-mass time.
# Out:
# Results of Dickey-Fuller Test
# Test Statistic                 -3.104698
# p-value                         0.026207
# #Lags Used                      0.000000
# Number of Observations Used    29.000000
# Critical Value (1%)            -3.679060
# Critical Value (5%)            -2.967882
# Critical Value (10%)           -2.623158
# dtype: float64

# %% [markdown]
# ### ARIMA (not auto ARIMA)

# %%
# Differencing.
def differencing(ts):
    ts_diff = ts - ts.shift(periods=1)
    ts_diff.dropna(inplace=True)
    return ts_diff

ts_diff = differencing(ts)
_test_stationarity(ts=ts_diff, window=3)
# Out:
# Results of Dickey-Fuller Test
# Test Statistic                 -5.272368
# p-value                         0.000006
# #Lags Used                      1.000000
# Number of Observations Used    27.000000
# Critical Value (1%)            -3.699608
# Critical Value (5%)            -2.976430
# Critical Value (10%)           -2.627601
# dtype: float64

# %%
#ACF and PACF plots:
from statsmodels.tsa.stattools import acf, pacf
lag_acf = acf(ts_diff, nlags=20)
lag_pacf = pacf(ts_diff, nlags=20, method='ols')

#Plot ACF: 
plt.subplot(121) 
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_diff)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')
#Plot PACF:
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_diff)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# p – The lag value where the PACF chart crosses the upper confidence interval for the first time. If you notice closely, in this case p=2.
# q – The lag value where the ACF chart crosses the upper confidence interval for the first time. If you notice closely, in this case q=2.

# p=1
# q=1
# d=1

# %%
model = ARIMA(ts_diff, order=(1, 1, 1))  
results_ARIMA = model.fit(disp=-1)
plt.plot(ts_diff)
plt.plot(results_ARIMA.fittedvalues, color='red')
plt.title('RSS: %.4f'% sum((results_ARIMA.fittedvalues-ts_diff).dropna()**2))
# Out:
# /Users/slechwar/miniconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /Users/slechwar/miniconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# Text(0.5,1,'RSS: 2320465.1364')

# %%
predictions_ARIMA_diff = pd.Series(results_ARIMA.fittedvalues, copy=True)
print(predictions_ARIMA_diff.head())
# Out:
# year_month_dt
# 2013-06-01     -6.493132
# 2013-07-01    -13.939628
# 2013-08-01    220.165437
# 2013-09-01    169.315666
# 2013-10-01     38.442035
# dtype: float64

# %%
predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
print(predictions_ARIMA_diff_cumsum)
# Out:
# year_month_dt
# 2013-06-01      -6.493132
# 2013-07-01     -20.432761
# 2013-08-01     199.732676
# 2013-09-01     369.048342
# 2013-10-01     407.490377
# 2013-11-01     520.455889
# 2013-12-01     625.508119
# 2014-01-01     435.635625
# 2014-02-01     921.530351
# 2014-03-01     936.582743
# 2014-04-01    1137.388286
# 2014-05-01    1327.926878
# 2014-06-01    1322.211659
# 2014-07-01    1293.028019
# 2014-08-01    1374.406674
# 2014-09-01    1289.629106
# 2014-10-01    1217.710679
# 2014-11-01    1194.636394
# 2014-12-01    1026.710059
# 2015-01-01     568.271362
# 2015-02-01    1009.849889
# 2015-04-01    1519.891552
# 2015-05-01    1150.849082
# 2015-06-01    1107.982680
# 2015-07-01    1065.099870
# 2015-08-01     944.007963
# 2015-09-01     913.842605
# 2015-10-01     795.764433
# dtype: float64

# %%
predictions_ARIMA_org = pd.Series(ts.loc[ts.index[0]], index=ts.index)
predictions_ARIMA_org = predictions_ARIMA_org.add(predictions_ARIMA_diff_cumsum,fill_value=0)
predictions_ARIMA_org.head()
# Out:
# year_month_dt
# 2013-04-01     13.000000
# 2013-05-01     13.000000
# 2013-06-01      6.506868
# 2013-07-01     -7.432761
# 2013-08-01    212.732676
# dtype: float64

# %%
predictions_ARIMA = predictions_ARIMA_org
plt.plot(ts)
plt.plot(predictions_ARIMA)
plt.title('RMSE: %.4f'% np.sqrt(sum((predictions_ARIMA-ts)**2)/len(ts)))
# Out:
# Text(0.5,1,'RMSE: 595.6548')
